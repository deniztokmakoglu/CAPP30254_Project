# %%
import pandas as pd
import os

# %% [markdown]
# ## Reading the Data

# %%
claims_datas = [f"claims_{i}" for i in range(1, 6)]

# %%
claims_datas
# Out:
# ['claims_1', 'claims_2', 'claims_3', 'claims_4', 'claims_5']

# %%
cd ..
# Out:
# /Users/deniztokmakoglu/CAPP30254_Project

# %%
claims = pd.read_csv("Data/claims1.csv")

# %%
for i in range(2, 6):
    claims = claims.append(pd.read_csv(f"Data/claims{i}.csv"))

# %%
claims
# Out:
#         Unnamed: 0  reimb2010  reimb2008  reimb2009  age2010  male   race  \
# 0                0        390      320.0        360       97     0  White
# 1                1        970    58800.0       2740       79     0  White
# 2                2       5630      510.0       1580       87     0  White
# 3                3       3480     2930.0      49330       79     0  White
# 4                4        920     1500.0       1650       85     1  White
# ...            ...        ...        ...        ...      ...   ...    ...
# 204783     1023947       6620     2090.0       4070       54     1  Block
# 204784     1023948        490    12450.0       1560       70     1  White
# 204785     1023949        690     1370.0       2440       75     0  Other
# 204786     1023950       1140     6530.0       9220       78     0  White
# 204787     1023951       1620     4160.0      18490       67     0  White
#
#         heart.failure  kidney  cancer  ...  OfficeVisit  EyeExam  EKG  xray  \
# 0                   0       0       0  ...            4        1    0     1
# 1                   1       1       0  ...           12        0    2     8
# 2                   1       0       0  ...           10        0    1     2
# 3                   1       1       0  ...           14        1    1     6
# 4                   1       0       1  ...           16        2    1     3
# ...               ...     ...     ...  ...          ...      ...  ...   ...
# 204783              1       0       0  ...           12        3    3     5
# 204784              1       1       0  ...            6        0    0     2
# 204785              1       1       0  ...           12        1    2     6
# 204786              0       1       1  ...           20        0    4     2
# 204787              1       1       0  ...            4        0    0     2
#
#         CTScan  PhysicalTherapy  Ambulance    acuity  costTrend  \
# 0            0                0          0  0.235294  -0.018856
# 1            1                0          1  0.853591  -0.027265
# 2            1                1          0  0.175115   0.496742
# 3            4                3          3  0.709147   0.214955
# 4            0                1          0  0.174603   0.231568
# ...        ...              ...        ...       ...        ...
# 204783       0                0          3  0.194805   0.333441
# 204784       0                0          1  0.722341  -0.129291
# 204785       1                2          2  0.207349   0.183677
# 204786       2                1          0  0.121905   0.117923
# 204787       4                3          2  0.773510   0.037682
#
#         monthsWithClaims
# 0                      9
# 1                     21
# 2                     20
# 3                     19
# 4                     21
# ...                  ...
# 204783                22
# 204784                15
# 204785                19
# 204786                23
# 204787                22
#
# [1023948 rows x 29 columns]

# %%
import numpy as np
import warnings
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
warnings.filterwarnings('ignore')
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %%
def normalize(df, scaler=None):
    '''
    If scaler is not none, use given scaler's means and sds to normalize
    (used for test set case)
    '''
    #Will not normalize the response (or outcomes), only the predictors
    (features)
    #Normalizing train set
    if(scaler is None):
        scaler = StandardScaler()
        normalized_features = scaler.fit_transform(df)
    #Normalizing test set
    else:
        normalized_features = scaler.transform(df)
        outcomes = df.iloc[:,-1]
        normalized_df = pd.DataFrame(normalized_features)
    normalized_df.index=df.index
    normalized_df.columns=df.columns
    return normalized_df, scaler

# %%
train, test = train_test_split(
claims,
test_size=0.20, random_state = 505)

# %%
test
# Out:
#         Unnamed: 0  reimb2010  reimb2008  reimb2009  age2010  male   race  \
# 101383      510965        530     1780.0       1130       68     0  White
# 5767        824931       1070      560.0        910       70     0  White
# 36992       446574        110     1110.0       1790       46     0  White
# 78298       897462        780      700.0        640       61     0  White
# 46939       251730       1450      240.0        530       70     1  White
# ...            ...        ...        ...        ...      ...   ...    ...
# 138880      548462       3280     3860.0       6730       86     0  White
# 80166       489748       1680      950.0       1550       77     0  White
# 135287      749660        730      240.0        770       64     0  White
# 173593      378384       1610     3280.0       3500       44     0  Block
# 203483      613065       1430    53210.0      23200       76     0  White
#
#         heart.failure  kidney  cancer  ...  OfficeVisit  EyeExam  EKG  xray  \
# 101383              0       0       0  ...           13        5    0     2
# 5767                1       0       0  ...            7        1    0     3
# 36992               0       1       0  ...            8        0    1     3
# 78298               0       0       1  ...           11        0    1     0
# 46939               0       0       0  ...            3        0    1     0
# ...               ...     ...     ...  ...          ...      ...  ...   ...
# 138880              1       1       0  ...           16        1    0     3
# 80166               1       0       0  ...            5        0    2     0
# 135287              1       0       0  ...            2        0    1     1
# 173593              1       1       1  ...           30        1    6     9
# 203483              1       1       0  ...            8        1    6     8
#
#         CTScan  PhysicalTherapy  Ambulance    acuity  costTrend  \
# 101383       0                6          0  0.185567  -0.045969
# 5767         0                1          1  0.142857   0.226803
# 36992        1                0          0  0.293103   0.105130
# 78298        1                1          0  0.171642   0.070622
# 46939        0                0          0  0.194805   0.449534
# ...        ...              ...        ...       ...        ...
# 138880       1                4          2  0.380548   0.127916
# 80166        0                1          0  0.172000   0.125199
# 135287       0                1          0  0.207921   0.295881
# 173593       0                3          3  0.115044   0.117003
# 203483       1                3          1  0.667845  -0.140962
#
#         monthsWithClaims
# 101383                15
# 5767                  15
# 36992                 16
# 78298                 14
# 46939                  9
# ...                  ...
# 138880                23
# 80166                 18
# 135287                12
# 173593                21
# 203483                19
#
# [204790 rows x 29 columns]

# %%
train_features_officevisit = train.loc[:,"OfficeVisit"]
test_features_officevisit = test.loc[:,"OfficeVisit"]
train_targets_reimb2010 = train.loc[:,"reimb2010"]

test_features_tmin = df_test.loc[:,"TMIN"]
test_features_count= test.loc[:,"COUNT TRIPS"]

# %%
regr1 = linear_model.LinearRegression()
regr1.fit(np.array(train_features_tmax).reshape(-1,1), train_targets_cou
nt)
